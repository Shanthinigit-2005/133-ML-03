# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
data = pd.read_csv(r"C:\Users\sanja\Downloads\train.csv")

# %%
data = data.dropna(subset=["news", "label"])


X = data["news"]
y = data["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=5000
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)
model = LogisticRegression(max_iter=1000)
model.fit(X_train_tfidf, y_train)

y_pred = model.predict(X_test_tfidf)

accuracy = accuracy_score(y_test, y_pred)

print("Fake News Detection using Machine Learning")
print("-------------------------------------------")
print("Algorithm: Logistic Regression")
print("Accuracy:", round(accuracy * 100, 2), "%")

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

news = input("\nEnter a news article: ")

news_tfidf = vectorizer.transform([news])
prediction = model.predict(news_tfidf)

print("\nPrediction:", prediction[0])
# Out:
# Fake News Detection using Machine Learning
# -------------------------------------------
# Algorithm: Logistic Regression
# Accuracy: 60.25 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.55      0.44      0.49       888
#         True       0.63      0.73      0.67      1160
#
#     accuracy                           0.60      2048
#    macro avg       0.59      0.58      0.58      2048
# weighted avg       0.60      0.60      0.59      2048
# Enter a news article:  the government announced a new education policy
# Prediction: False
